# %% [markdown]
# # Stage 5 - Model Evaluation
#
# This notebook evaluates classification, retrieval, prediction, and error analysis for the full CBR pipeline.

# %% [markdown]
# ## What this notebook does
# - Evaluate accuracy, precision, recall, and F1 for SVM and Naive Bayes.
# - Evaluate retrieval metrics at top-k.
# - Save confusion matrix, error analysis, and summary charts.

# %%
# %run ../05_evaluation.py
