# %% [markdown]
# # Stage 1 - Scraping and Preprocessing
#
# This notebook runs the first stage of the pipeline and builds the raw case base from the Mahkamah Agung decisions.

# %% [markdown]
# ## What this notebook does
# - Collect case links from the PN Bandung PMH directory.
# - Download and clean decision text.
# - Save raw text, extracted text, tokens, PDFs, and metadata.

# %%
# %run ../01_scraping.py
