# %% [markdown]
# # Stage 2 - Case Representation
#
# This notebook transforms the raw case texts into a structured dataset for retrieval and prediction.

# %% [markdown]
# ## What this notebook does
# - Extract litigant names, legal articles, factual summary, and legal arguments.
# - Build `cases.csv` and `cases.json` in `data/processed/`.

# %%
# %run ../02_representation.py
