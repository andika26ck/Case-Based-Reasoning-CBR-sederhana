# %% [markdown]
# # Stage 3 - Case Retrieval
#
# This notebook trains the retrieval models, evaluates similarity-based retrieval, and generates evaluation queries.

# %% [markdown]
# ## What this notebook does
# - Train TF-IDF, SVM, and Naive Bayes models.
# - Build cosine similarity retrieval for TF-IDF and BERT.
# - Save model artifacts and `queries.json`.

# %%
# %run ../03_retrieval.py
