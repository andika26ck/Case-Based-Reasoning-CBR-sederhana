# %% [markdown]
# # Stage 4 - Case Solution Reuse
#
# This notebook reuses the most similar cases to predict the outcome for new queries.

# %% [markdown]
# ## What this notebook does
# - Load the train split and retrieval artifacts.
# - Apply majority vote or weighted similarity to choose the solution.
# - Save predictions to `data/results/predictions.csv`.

# %%
# %run ../04_predict.py
